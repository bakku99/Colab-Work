# %% [markdown]
# <a href="https://colab.research.google.com/github/bakku99/Colab-Work/blob/main/Indesign_Files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import zipfile
import os

# Upload your large zip file
uploaded = files.upload()

# Extract the uploaded zip
for zip_filename in uploaded.keys():
    if zip_filename.endswith('.zip'):
        with zipfile.ZipFile(zip_filename, 'r') as zip_ref:
            zip_ref.extractall('/content/IndesignRoot')
        print(f"✅ Extracted {zip_filename}")
# Out:
#      <input type="file" id="files-33efc142-a6d1-4c52-9d0c-a0883ca4e9e1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-33efc142-a6d1-4c52-9d0c-a0883ca4e9e1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Path to the nested zip
nested_zip_path = '/content/IndesignRoot/4087579-2024_DD_Template_Packaged_1_26.zip'

# Check existence
if os.path.exists(nested_zip_path):
    with zipfile.ZipFile(nested_zip_path, 'r') as zip_ref:
        zip_ref.extractall('/content/IndesignTemplate')
    print("✅ Extracted 2024_D&D_Template_Packaged to /content/IndesignTemplate")
else:
    print("❌ Could not find the nested zip file.")
# Out:
# ✅ Extracted 2024_D&D_Template_Packaged to /content/IndesignTemplate

# %%
# Utility function to print directory tree
def list_files(startpath):
    for root, dirs, files in os.walk(startpath):
        level = root.replace(startpath, '').count(os.sep)
        indent = ' ' * 2 * level
        print(f"{indent}{os.path.basename(root)}/")
        subindent = ' ' * 2 * (level + 1)
        for f in files:
            print(f"{subindent}{f}")

# List contents of the final extracted template folder
list_files('/content/IndesignTemplate')
# Out:
# IndesignTemplate/
#   __MACOSX/
#     2024_D&D_Template_Packaged/
#       ._2024_D&D_Template_FreeFonts.idml
#       ._2024_D&D_Template_AdobeFonts.idml
#       ._2024_D&D_Template_AdobeFonts_TEMPLATE.indt
#       ._ChangeLog.txt
#       ._2024_D&D_Template_FreeFonts.indd
#       ._2024_D&D_Template_AdobeFonts.indd
#       ._2024_D&D_Template_FreeFonts_TEMPLATE.indt
#       Document fonts/
#         ._OPTIPegasus-Semibold.otf
#         ._Scaly Sans Caps.otf
#       Links/
#         ._background_top-two-thirds.png
#         ._background_top-third.png
#         ._background_top-half.png
#         ._watercolour_03.jpg
#         ._background2024.jpg
#         ._watercolour_03.png
#         ._background_left-half.png
#         ._background_bottom-two-thirds.png
#         ._background_bottom-half.png
#         ._jelly.png
#         ._background_bottom-third.png
#         ._DMsGuildProductLogoLarge.png
#         ._background_right-half.png
#   2024_D&D_Template_Packaged/
# ...

# %%
import shutil
from zipfile import ZipFile

# Copy IDML file to a .zip so we can unzip it (IDML is just a zip archive)
idml_path = '/content/IndesignTemplate/2024_D&D_Template_Packaged/2024_D&D_Template_AdobeFonts.idml'
idml_extract_path = '/content/IDML_Extracted'

shutil.copy(idml_path, '/content/template.zip')

# Extract
with ZipFile('/content/template.zip', 'r') as zip_ref:
    zip_ref.extractall(idml_extract_path)

# Show top-level files
print("✅ Extracted IDML contents:")
for f in os.listdir(idml_extract_path):
    print(" -", f)
# Out:
# ✅ Extracted IDML contents:
#  - MasterSpreads
#  - META-INF
#  - Resources
#  - Stories
#  - Spreads
#  - XML
#  - mimetype
#  - designmap.xml

# %%
import os

# List contents of MasterSpreads and Resources
print("📄 MasterSpreads:")
for f in os.listdir('/content/IDML_Extracted/MasterSpreads'):
    print(" -", f)

print("\n📁 Resources:")
for f in os.listdir('/content/IDML_Extracted/Resources'):
    print(" -", f)
# Out:
# 📄 MasterSpreads:
#  - MasterSpread_uc54.xml
#  - MasterSpread_u1bc.xml
#  - MasterSpread_u1d3c.xml
#  - MasterSpread_uf4f.xml
#  - MasterSpread_u1a3e.xml
#  - MasterSpread_u24f0.xml
#  - MasterSpread_u256d.xml
#  - MasterSpread_u19c3.xml
#  - MasterSpread_u1d96.xml
#  - MasterSpread_ud6.xml
#  - MasterSpread_u2a7d.xml
#
# 📁 Resources:
#  - Graphic.xml
#  - Styles.xml
#  - Fonts.xml
#  - Preferences.xml

# %%
# Display first 100 lines of Styles.xml to inspect formatting
with open('/content/IDML_Extracted/Resources/Styles.xml', 'r', encoding='utf-8') as f:
    for i in range(100):
        print(f.readline().strip())
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <idPkg:Styles xmlns:idPkg="http://ns.adobe.com/AdobeInDesign/idml/1.0/packaging" DOMVersion="20.2">
# <RootCharacterStyleGroup Self="u80">
# <CharacterStyle Self="CharacterStyle/$ID/[No character style]" Imported="false" SplitDocument="false" EmitCss="true" StyleUniqueId="$ID/" IncludeClass="true" ExtendedKeyboardShortcut="0 0 0" Name="$ID/[No character style]" />
# <CharacterStyle Self="CharacterStyle/Booksanity - Bold Italic" Imported="false" SplitDocument="false" EmitCss="true" StyleUniqueId="3768cacd-e4e8-4697-a86d-20db8ab693a7" IncludeClass="true" ExtendedKeyboardShortcut="0 0 0" KeyboardShortcut="0 0" Name="Booksanity - Bold Italic" FontStyle="Bold Italic">
# <Properties>
# <BasedOn type="string">$ID/[No character style]</BasedOn>
# <PreviewColor type="enumeration">Nothing</PreviewColor>
# </Properties>
# </CharacterStyle>
# ...

# %%
# Show first 100 lines of one master spread layout
with open('/content/IDML_Extracted/MasterSpreads/MasterSpread_uc54.xml', 'r', encoding='utf-8') as f:
    for i in range(100):
        print(f.readline().strip())
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <idPkg:MasterSpread xmlns:idPkg="http://ns.adobe.com/AdobeInDesign/idml/1.0/packaging" DOMVersion="20.2">
# <MasterSpread Self="uc54" Name="B-Blank" NamePrefix="B" BaseName="Blank" ShowMasterItems="true" PageCount="2" OverriddenPageItemProps="" PrimaryTextFrame="n" ItemTransform="1 0 0 1 0 0">
# <Properties>
# <PageColor type="enumeration">UseMasterColor</PageColor>
# </Properties>
# <Page Self="uc61" TabOrder="" AppliedMaster="n" OverrideList="" MasterPageTransform="1 0 0 1 0 0" Name="B" AppliedTrapPreset="TrapPreset/$ID/kDefaultTrapStyleName" GeometricBounds="0 0 792 612" ItemTransform="1 0 0 1 -612 -396" AppliedAlternateLayout="n" LayoutRule="Off" SnapshotBlendingMode="IgnoreLayoutSnapshots" OptionalPage="false" GridStartingPoint="TopOutside" UseMasterGrid="true">
# <Properties>
# <PageColor type="enumeration">UseMasterColor</PageColor>
# </Properties>
# ...
